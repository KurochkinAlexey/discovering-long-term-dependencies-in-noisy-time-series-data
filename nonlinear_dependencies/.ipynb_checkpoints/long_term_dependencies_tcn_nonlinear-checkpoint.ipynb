# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader

# %%
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

# %%
length = 100000
train_length = 80000

# %%
max_lag = 300

# %%
np.random.seed(42)
X0 = 1*np.sin(np.linspace(0, length//10, length)*0.5)*cos(np.linspace(0, length//10, length)*2) + np.random.randn(length)
X1 = 1*np.sin(np.linspace(0, length//10, length)*2) + cos(np.linspace(0, length//10, length)*0.5) + np.random.randn(length)
X2 = np.random.randn(length)
X3 = np.random.randn(length)*0.1
X4 = np.random.randn(length)*0.1
X5 = np.random.randn(length)*0.1
for t in range(max_lag, length):
    X2[t] += X0[t-10]*X1[t-100] + X0[t-70]*X1[t-40]
    X3[t] += X2[t-150]*X1[t-20]-5*np.sin(X0[t-100])
    X4[t] += X3[t-80]/(20 + X2[t-40]) 
    X5[t] += X0[t-10]*X1[t-20]+X2[t-110]*X4[t-120]+X4[t-210]*X5[t-270]

# %%
plt.plot(X0[:1000])

# %%
plt.plot(X1[:1000])

# %%
plt.plot(X2[:1000])

# %%
plt.plot(X3[:100000])

# %%
plt.plot(X4)

# %%
plt.plot(X5[:10000])

# %%
import torch
import torch.nn as nn
from torch.nn.utils import weight_norm
class TCNTemporalBlock(nn.Module):
    def __init__(self, input_channels, output_channels, kernel_size, dilation):
        super().__init__()
        padding = int(dilation*(kernel_size-1))
        self.pad = nn.ConstantPad1d((padding, 0), 0)
        self.conv1 = weight_norm(nn.Conv1d(input_channels, output_channels, kernel_size, dilation=dilation))
        self.conv2 = weight_norm(nn.Conv1d(output_channels, output_channels, kernel_size, dilation=dilation))
        self.residual = nn.Conv1d(input_channels, output_channels, 1)
        
    def forward(self, x):
        out = self.pad(x)
        out = torch.relu(self.conv1(out))
        out = self.pad(out)
        out = torch.relu(self.conv2(out))
        y = self.residual(x)
        out = torch.relu(out + y)
        return out
    

class TCN(nn.Module):
    def __init__(self, input_dim, n_layers, n_channels=32, kernel_size=3):
        super().__init__()
        self.first_layer = TCNTemporalBlock(input_dim, n_channels, kernel_size, 1)
        self.tcn_layers = nn.ModuleList([TCNTemporalBlock(n_channels, n_channels, kernel_size, 2**(i+1)) for i in range(n_layers-1)])
        self.n_layers = n_layers
        self.output_transform = nn.Linear(n_channels, 1)
    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.first_layer(x)
        for i in range(self.n_layers-1):
            x = self.tcn_layers[i](x)
        x = x[..., -1]
        out = self.output_transform(x)
        return out.squeeze(1)

# %%
depth = 300
epochs = 300
importance_calculation_steps = 20
early_stopping_epochs = 50

# %%
from tqdm import tqdm_notebook

# %%
X_ = np.concatenate([X0.reshape(-1, 1), 
                    X1.reshape(-1, 1),
                    X2.reshape(-1, 1),
                    X3.reshape(-1, 1),
                    X4.reshape(-1, 1),
                    X5.reshape(-1, 1)], axis=1)

# %%
X = np.zeros((len(X_), depth, X_.shape[1]))
for i in range(X_.shape[1]):
    for j in range(depth):
        X[:, j, i] = pd.Series(X_[:, i]).shift(depth - j - 1).bfill()

# %% [markdown]
# ### Predicting X2

# %%
y = pd.Series(X2).shift(-1).ffill().values

# %%
X = X[max_lag:]
y = y[max_lag:]

# %%
X_train = X[:train_length]
X_test = X[train_length:]

y_train = y[:train_length]
y_test = y[train_length:]

# %%
X_train_min, X_train_max = X_train.min(axis=0), X_train.max(axis=0)
y_train_min, y_train_max = y_train.min(axis=0), y_train.max(axis=0)

# %%
X_train = (X_train - X_train_min)/(X_train_max - X_train_min + 1e-9)
X_test = (X_test - X_train_min)/(X_train_max - X_train_min + 1e-9)

y_train = (y_train - y_train_min)/(y_train_max - y_train_min + 1e-9)
y_test = (y_test - y_train_min)/(y_train_max - y_train_min + 1e-9)

# %%
X_train_t = torch.Tensor(X_train)
X_test_t = torch.Tensor(X_test)

y_train_t = torch.Tensor(y_train)
y_test_t = torch.Tensor(y_test)

# %%
train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), shuffle=True, batch_size=256)
test_loader = DataLoader(TensorDataset(X_test_t, y_test_t), shuffle=False, batch_size=256)

# %%
model = TCN(X_train_t.shape[2], 9).cuda()

opt = torch.optim.Adam(model.parameters(), lr=0.001)

loss = nn.MSELoss()

# %%
val_loss = 999
counter = 0
for e in range(epochs):
    train_loss = 0
    model.train()
    for batch_x, batch_y in tqdm_notebook(train_loader):
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()
        opt.zero_grad()
        output = model(batch_x)
        l = loss(output, batch_y)
        l.backward()
        opt.step()
        train_loss+=l.item()*batch_x.shape[0]
    true = []
    preds = []
    model.eval()
    with torch.no_grad():
        for batch_x, batch_y in test_loader:
            batch_x = batch_x.cuda()
            output = model(batch_x)
            true.append(batch_y.numpy())
            preds.append(output.detach().cpu().numpy())
    preds = np.concatenate(preds)
    true = np.concatenate(true)
    mse = mean_squared_error(true, preds)
    r2 = r2_score(true, preds)
    print("Iter: ", e, "train: ", train_loss/len(X_train_t), "mse: ", mse, "r2: ", r2)
    if val_loss > mse:
        val_loss = mse
        torch.save(model.state_dict(), "tcn_nonlinear_X2.pt")
        counter = 0
    else:
        counter += 1

    if counter == early_stopping_epochs:
        break
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  0 train:  0.012167606975883245 mse:  0.005259521 r2:  8.3077631716999e-05
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  1 train:  0.005192683883011341 mse:  0.0052506165 r2:  0.001775977406590079
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  2 train:  0.0048312554828822615 mse:  0.004672458 r2:  0.11169288119669485
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  3 train:  0.004583331850171089 mse:  0.0046074465 r2:  0.12405262998302902
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  4 train:  0.004559558158367873 mse:  0.0046489807 r2:  0.11615632829852107
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  5 train:  0.004556252006441355 mse:  0.0046201656 r2:  0.12163449778535351
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  6 train:  0.004546415490657091 mse:  0.0045946185 r2:  0.12649138715509844
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  7 train:  0.004551336409151554 mse:  0.004593814 r2:  0.12664439166918584
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  8 train:  0.004506775577366352 mse:  0.004574365 r2:  0.1303418331337438
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  9 train:  0.00436559536382556 mse:  0.003994267 r2:  0.24062759986850413
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  10 train:  0.003472771902754903 mse:  0.0032737395 r2:  0.3776111201558332
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  11 train:  0.0028745731465518475 mse:  0.0025823845 r2:  0.5090484535522822
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  12 train:  0.002098736844584346 mse:  0.0015246826 r2:  0.7101340577352886
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  13 train:  0.001217190306261182 mse:  0.001220481 r2:  0.7679675356770895
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  14 train:  0.0010533019446767866 mse:  0.0009924516 r2:  0.8113194830908195
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  15 train:  0.0010176256142556668 mse:  0.0010647393 r2:  0.7975764601107052
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  90 train:  0.0007829530742019415 mse:  0.0009899343 r2:  0.8117980696106748
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  91 train:  0.0007939522720873356 mse:  0.00097045465 r2:  0.8155014462246074
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  92 train:  0.000791064939275384 mse:  0.0009816445 r2:  0.8133740823824622
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  93 train:  0.0007935242854990065 mse:  0.0009786502 r2:  0.813943343966403
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  94 train:  0.000770699867606163 mse:  0.0009740567 r2:  0.8148166392581809
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  95 train:  0.000783865244500339 mse:  0.0010104344 r2:  0.8079006823387092
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  96 train:  0.0007901974570937454 mse:  0.0009765076 r2:  0.814350688495492
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  97 train:  0.000770870822109282 mse:  0.0010469345 r2:  0.8009614609364988

# %%
regularizer_coeff1 = 0.0005
regularizer_coeff2 = 0.00001
scaling_coeff = 0.5
importance_lr = 0.1

# %%
model.load_state_dict(torch.load("tcn_nonlinear_X2.pt"))

bce_loss = nn.BCELoss()
mse_loss = nn.MSELoss()

model.eval()

importance_map = []
for batch_x, batch_y in tqdm_notebook(test_loader):
    batch_x = batch_x.cuda()
    #batch_y = batch_y.cuda()
    bx = batch_x
    y = model(batch_x)
    mask = nn.Parameter(-scaling_coeff*torch.randn_like(bx))
    opt = torch.optim.RMSprop(nn.ParameterList([mask]), lr=importance_lr)
    for e in range(importance_calculation_steps):
        opt.zero_grad()
        model.zero_grad()
        model.eval()
        y = y.detach()
        M = torch.sigmoid(mask)
        x_hat = bx*M
        y_hat = model(x_hat)
        l = mse_loss(y_hat, y)
        l += regularizer_coeff1*torch.sum(torch.abs(M))
        ones = torch.zeros_like(bx)
        ones[M>0.5] = 1
        l += 0.5*bce_loss(M, ones)
        l.backward()
        opt.step()
    M = torch.sigmoid(mask)
    #ms = ms.detach().cpu().numpy()
    print(M.max())
    thresholds = {}
    with torch.no_grad():
        for t in np.linspace(M.min().item(), M.max().item(), 100):
            M_clone = M.clone()
            M_clone[M_clone>t] = 1
            M_clone[M_clone<=t] = 0
            x_hat = bx*M_clone
            y_hat = model(x_hat)
            l = mse_loss(y_hat, y)
            l += regularizer_coeff2*torch.sum(torch.abs(M_clone))
            thresholds[l.item()] = t
    t = thresholds[min(thresholds.keys())]
    M = M.detach().cpu().numpy()
    M[M>t] = 1
    M[M<=t] = 0
    importance_map.append(np.abs(M))

importance_map = np.concatenate(importance_map)
importance_map = np.mean(importance_map, axis=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if __name__ == '__main__':
# HBox(children=(FloatProgress(value=0.0, max=77.0), HTML(value='')))
# tensor(0.3315, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2073, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2243, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3430, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2611, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3222, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2268, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2841, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2600, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3059, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2805, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2687, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2718, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2788, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3027, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2122, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3199, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2611, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3045, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2211, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2330, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2740, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2848, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3215, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2060, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2917, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2255, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0658, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3120, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2477, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2599, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2720, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1810, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2601, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3009, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2072, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2884, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2649, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2780, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2768, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2547, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2754, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2606, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2884, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3095, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1637, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2666, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2970, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2995, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3018, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2923, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2819, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2699, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2805, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2939, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3597, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2339, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3588, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2317, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3118, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2861, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2953, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2666, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2462, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2645, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2363, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2968, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3231, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2725, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2543, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1042, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2494, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1887, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3550, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.3029, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2861, device='cuda:0', grad_fn=<MaxBackward1>)

# %%
importance_map.max()
# Out:
# 0.09248731

# %%
plt.figure(figsize=(200, 100))
plt.imshow(importance_map.T)
plt.xticks(np.arange(depth), ["t-{}".format(i) for i in range(depth,0,-1)], rotation=90)
plt.yticks(np.arange(6), ['X{}'.format(i) for i in range(6)])
# Out:
# ([<matplotlib.axis.YTick at 0x7f4e28539080>,
#   <matplotlib.axis.YTick at 0x7f4e285392e8>,
#   <matplotlib.axis.YTick at 0x7f4e2868f748>,
#   <matplotlib.axis.YTick at 0x7f4e26215a20>,
#   <matplotlib.axis.YTick at 0x7f4e26215eb8>,
#   <matplotlib.axis.YTick at 0x7f4e26221390>],
#  [Text(0, 0, 'X0'),
#   Text(0, 1, 'X1'),
#   Text(0, 2, 'X2'),
#   Text(0, 3, 'X3'),
#   Text(0, 4, 'X4'),
#   Text(0, 5, 'X5')])

# %% [markdown]
# ### Signals with highest importance

# %%
#X1[t-100], X0[t-70], X1[t-40], X0[t-10]

# %% [markdown]
# ### True dependencies

# %%
#X2[t] += X0[t-10]*X1[t-100] + X0[t-70]*X1[t-40]

# %%
TP = 4
FP = 0
FN = 0
precision1 = TP/(TP + FP)
recall1 = TP/(TP + FN)
precision1, recall1
# Out:
# (1.0, 1.0)

# %% [markdown]
# ### Predicting X3

# %%
y = pd.Series(X3).shift(-1).ffill().values
y = y[max_lag:]
y_train = y[:train_length]
y_test = y[train_length:]

y_train_min, y_train_max = y_train.min(axis=0), y_train.max(axis=0)

y_train = (y_train - y_train_min)/(y_train_max - y_train_min + 1e-9)
y_test = (y_test - y_train_min)/(y_train_max - y_train_min + 1e-9)

y_train_t = torch.Tensor(y_train)
y_test_t = torch.Tensor(y_test)

train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), shuffle=True, batch_size=256)
test_loader = DataLoader(TensorDataset(X_test_t, y_test_t), shuffle=False, batch_size=256)

# %%
model = TCN(X_train_t.shape[2], 9).cuda()

opt = torch.optim.Adam(model.parameters(), lr=0.001)

loss = nn.MSELoss()

# %%
val_loss = 999
counter = 0
#model.load_state_dict(torch.load("tcn_nonlinear_X3.pt"))
for e in range(epochs):
    train_loss = 0
    
    model.train()
    for batch_x, batch_y in tqdm_notebook(train_loader):
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()
        opt.zero_grad()
        output = model(batch_x)
        l = loss(output, batch_y)
        l.backward()
        opt.step()
        train_loss+=l.item()*batch_x.shape[0]
    true = []
    preds = []
    model.eval()
    with torch.no_grad():
        for batch_x, batch_y in test_loader:
            batch_x = batch_x.cuda()
            output = model(batch_x)
            true.append(batch_y.numpy())
            preds.append(output.detach().cpu().numpy())
    preds = np.concatenate(preds)
    true = np.concatenate(true)
    mse = mean_squared_error(true, preds)
    r2 = r2_score(true, preds)
    print("Iter: ", e, "train: ", train_loss/len(X_train_t), "mse: ", mse, "r2: ", r2)
    if val_loss > mse:
        val_loss = mse
        torch.save(model.state_dict(), "tcn_nonlinear_X3.pt")
        counter = 0
    else:
        counter += 1
 
    if counter == early_stopping_epochs:
        break
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  0 train:  0.020632632748782635 mse:  0.003968131 r2:  -0.00039030083641322655
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  1 train:  0.0039024675596505405 mse:  0.004006316 r2:  -0.010016983723168282
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  2 train:  0.003912067610025406 mse:  0.0039666165 r2:  -8.433704923760388e-06
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  78 train:  0.0014503214094787836 mse:  0.0018609785 r2:  0.530835810245117
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  79 train:  0.0014323741605505348 mse:  0.0019054657 r2:  0.5196203655922353
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  80 train:  0.0014361260952427983 mse:  0.0019664022 r2:  0.5042577874605736
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  81 train:  0.0014427958277985454 mse:  0.0019100328 r2:  0.518468928319794
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  82 train:  0.0014241647353395819 mse:  0.0018546078 r2:  0.5324419132364504
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  83 train:  0.0014146414341405034 mse:  0.0019405092 r2:  0.5107856540353132
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  84 train:  0.0014152365427464247 mse:  0.0017871258 r2:  0.5494545284054051
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  85 train:  0.001402200723811984 mse:  0.001852406 r2:  0.5329970268222166
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  86 train:  0.001392495097965002 mse:  0.0018688039 r2:  0.5288629879252564
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  87 train:  0.0013931056387722492 mse:  0.0017921587 r2:  0.5481857444428309
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  88 train:  0.0013780270481482148 mse:  0.0018151428 r2:  0.5423912989812775
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  89 train:  0.001382099362835288 mse:  0.0018637134 r2:  0.5301463340636825
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  90 train:  0.0013811399636790157 mse:  0.0020488824 r2:  0.4834640469933683
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  91 train:  0.0013861751626245678 mse:  0.0018581513 r2:  0.5315486127021677
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  92 train:  0.001366729237139225 mse:  0.0018935681 r2:  0.522619799877786
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  93 train:  0.0013530852718278766 mse:  0.0018643646 r2:  0.5299821574221633
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  94 train:  0.001363235068321228 mse:  0.0018565967 r2:  0.5319405006117264
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  95 train:  0.0013624644348397851 mse:  0.0018925882 r2:  0.5228667951854298

# %%
model.load_state_dict(torch.load("tcn_nonlinear_X3.pt"))

bce_loss = nn.BCELoss()
mse_loss = nn.MSELoss()

model.eval()

importance_map = []
for batch_x, batch_y in tqdm_notebook(test_loader):
    batch_x = batch_x.cuda()
    #batch_y = batch_y.cuda()
    bx = batch_x
    y = model(batch_x)
    mask = nn.Parameter(-scaling_coeff*torch.randn_like(bx))
    opt = torch.optim.RMSprop(nn.ParameterList([mask]), lr=importance_lr)
    for e in range(importance_calculation_steps):
        opt.zero_grad()
        model.zero_grad()
        model.eval()
        y = y.detach()
        M = torch.sigmoid(mask)
        x_hat = bx*M
        y_hat = model(x_hat)
        l = mse_loss(y_hat, y)
        l += regularizer_coeff1*torch.sum(torch.abs(M))
        ones = torch.zeros_like(bx)
        ones[M>0.5] = 1
        l += 0.5*bce_loss(M, ones)
        l.backward()
        opt.step()
    M = torch.sigmoid(mask)
    #ms = ms.detach().cpu().numpy()
    print(M.max())
    thresholds = {}
    with torch.no_grad():
        for t in np.linspace(M.min().item(), M.max().item(), 100):
            M_clone = M.clone()
            M_clone[M_clone>t] = 1
            M_clone[M_clone<=t] = 0
            x_hat = bx*M_clone
            y_hat = model(x_hat)
            l = mse_loss(y_hat, y)
            l += regularizer_coeff2*torch.sum(torch.abs(M_clone))
            thresholds[l.item()] = t
    t = thresholds[min(thresholds.keys())]
    M = M.detach().cpu().numpy()
    M[M>t] = 1
    M[M<=t] = 0
    importance_map.append(np.abs(M))

importance_map = np.concatenate(importance_map)
importance_map = np.mean(importance_map, axis=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if __name__ == '__main__':
# HBox(children=(FloatProgress(value=0.0, max=77.0), HTML(value='')))
# tensor(0.0297, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0301, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0297, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0299, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0295, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0295, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0293, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0292, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0294, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0301, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0293, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0293, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0300, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0291, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0298, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0293, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0302, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0295, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0291, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0295, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0298, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0290, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0292, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0298, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0301, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0299, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0294, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0306, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0291, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0291, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0299, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0291, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0291, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0306, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0293, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0298, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0299, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0303, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0297, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0292, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0295, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0295, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0291, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0293, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0295, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0294, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0294, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0294, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0295, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0291, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0293, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0291, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0297, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0293, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0300, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0294, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0300, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0295, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0291, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0292, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0295, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0301, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0289, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0297, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0296, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0298, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0292, device='cuda:0', grad_fn=<MaxBackward1>)

# %%
plt.figure(figsize=(200, 100))
plt.imshow(importance_map.T)
plt.xticks(np.arange(depth), ["t-{}".format(i) for i in range(depth,0,-1)], rotation=90)
plt.yticks(np.arange(6), ['X{}'.format(i) for i in range(6)])
# Out:
# ([<matplotlib.axis.YTick at 0x7f4da737d668>,
#   <matplotlib.axis.YTick at 0x7f4da737dd68>,
#   <matplotlib.axis.YTick at 0x7f4da74cbc50>,
#   <matplotlib.axis.YTick at 0x7f4da718e2e8>,
#   <matplotlib.axis.YTick at 0x7f4da718e780>,
#   <matplotlib.axis.YTick at 0x7f4da718ec18>],
#  [Text(0, 0, 'X0'),
#   Text(0, 1, 'X1'),
#   Text(0, 2, 'X2'),
#   Text(0, 3, 'X3'),
#   Text(0, 4, 'X4'),
#   Text(0, 5, 'X5')])

# %% [markdown]
# ### Signals with highest importance

# %%
#

# %% [markdown]
# ### True dependencies

# %%
#X3[t] += X2[t-150]*X1[t-20]-5*np.sin(X0[t-100])

# %%
TP = 0
FP = 0
FN = 0
precision2 = TP/(TP + FP + 1e-9)
recall2 = TP/(TP + FN + 1e-9)
precision2, recall2
# Out:
# (0.0, 0.0)

# %% [markdown]
# ### Predicting X4

# %%
y = pd.Series(X4).shift(-1).ffill().values
y = y[max_lag:]
y_train = y[:train_length]
y_test = y[train_length:]

y_train_min, y_train_max = y_train.min(axis=0), y_train.max(axis=0)

y_train = (y_train - y_train_min)/(y_train_max - y_train_min + 1e-9)
y_test = (y_test - y_train_min)/(y_train_max - y_train_min + 1e-9)

y_train_t = torch.Tensor(y_train)
y_test_t = torch.Tensor(y_test)

train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), shuffle=True, batch_size=256)
test_loader = DataLoader(TensorDataset(X_test_t, y_test_t), shuffle=False, batch_size=256)

# %%
model = TCN(X_train_t.shape[2], 9).cuda()

opt = torch.optim.Adam(model.parameters(), lr=0.001)

loss = nn.MSELoss()

# %%
val_loss = 999
counter = 0

for e in range(epochs):
    train_loss = 0
    
    model.train()
    for batch_x, batch_y in tqdm_notebook(train_loader):
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()
        opt.zero_grad()
        output = model(batch_x)
        l = loss(output, batch_y)
        l.backward()
        opt.step()
        train_loss+=l.item()*batch_x.shape[0]
    true = []
    preds = []
    model.eval()
    with torch.no_grad():
        for batch_x, batch_y in test_loader:
            batch_x = batch_x.cuda()
            output = model(batch_x)
            true.append(batch_y.numpy())
            preds.append(output.detach().cpu().numpy())
    preds = np.concatenate(preds)
    true = np.concatenate(true)
    mse = mean_squared_error(true, preds)
    r2 = r2_score(true, preds)
    print("Iter: ", e, "train: ", train_loss/len(X_train_t), "mse: ", mse, "r2: ", r2)
    if val_loss > mse:
        val_loss = mse
        torch.save(model.state_dict(), "tcn_nonlinear_X4.pt")
        counter = 0
    else:
        counter += 1

    if counter == early_stopping_epochs:
        break
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  75 train:  0.0005784347619861365 mse:  0.00073555467 r2:  0.8090018219930577
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  76 train:  0.0005801553348079324 mse:  0.0005997437 r2:  0.8442672416511937
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  77 train:  0.0005749318128917367 mse:  0.00064795493 r2:  0.8317484512351105
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  78 train:  0.0005841518900357187 mse:  0.00059436227 r2:  0.845664604671759
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  79 train:  0.000573878418840468 mse:  0.000621614 r2:  0.8385882902607589
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  80 train:  0.0005779497703537345 mse:  0.0005883522 r2:  0.8472252282200143
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  81 train:  0.0005707887627184391 mse:  0.0006086407 r2:  0.8419569984366734
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  82 train:  0.0005700511591508984 mse:  0.00059505424 r2:  0.8454849236970006
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  83 train:  0.0005722416181117296 mse:  0.0006588967 r2:  0.8289072545951657
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  84 train:  0.0005746493820101023 mse:  0.00059986167 r2:  0.8442366062163077
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  85 train:  0.0005766454055905342 mse:  0.0006942231 r2:  0.8197341970595043
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  86 train:  0.0005678738926537335 mse:  0.00061630964 r2:  0.8399656356223668
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  87 train:  0.000570680408552289 mse:  0.0005965522 r2:  0.8450959790930579
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  88 train:  0.0005757833377458155 mse:  0.00062194484 r2:  0.83850238036663
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  89 train:  0.0005747511887922883 mse:  0.00060117117 r2:  0.843896582061999
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  90 train:  0.0005705224729143083 mse:  0.0005908344 r2:  0.8465806965070237
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  91 train:  0.0005709880689159036 mse:  0.00066563446 r2:  0.8271576723797246
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=313.0), HTML(value='')))
# Iter:  92 train:  0.0005708777140825987 mse:  0.00061671203 r2:  0.8398611429798308

# %%
model.load_state_dict(torch.load("tcn_nonlinear_X4.pt"))

bce_loss = nn.BCELoss()
mse_loss = nn.MSELoss()

model.eval()

importance_map = []
for batch_x, batch_y in tqdm_notebook(test_loader):
    batch_x = batch_x.cuda()
    #batch_y = batch_y.cuda()
    bx = batch_x
    y = model(batch_x)
    mask = nn.Parameter(-scaling_coeff*torch.randn_like(bx))
    opt = torch.optim.RMSprop(nn.ParameterList([mask]), lr=importance_lr)
    for e in range(importance_calculation_steps):
        opt.zero_grad()
        model.zero_grad()
        model.eval()
        y = y.detach()
        M = torch.sigmoid(mask)
        x_hat = bx*M
        y_hat = model(x_hat)
        l = mse_loss(y_hat, y)
        l += regularizer_coeff1*torch.sum(torch.abs(M))
        ones = torch.zeros_like(bx)
        ones[M>0.5] = 1
        l += 0.5*bce_loss(M, ones)
        l.backward()
        opt.step()
    M = torch.sigmoid(mask)
    #ms = ms.detach().cpu().numpy()
    print(M.max())
    thresholds = {}
    with torch.no_grad():
        for t in np.linspace(M.min().item(), M.max().item(), 100):
            M_clone = M.clone()
            M_clone[M_clone>t] = 1
            M_clone[M_clone<=t] = 0
            x_hat = bx*M_clone
            y_hat = model(x_hat)
            l = mse_loss(y_hat, y)
            l += regularizer_coeff2*torch.sum(torch.abs(M_clone))
            thresholds[l.item()] = t
    t = thresholds[min(thresholds.keys())]
    M = M.detach().cpu().numpy()
    M[M>t] = 1
    M[M<=t] = 0
    importance_map.append(np.abs(M))

importance_map = np.concatenate(importance_map)
importance_map = np.mean(importance_map, axis=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if __name__ == '__main__':
# HBox(children=(FloatProgress(value=0.0, max=77.0), HTML(value='')))
# tensor(0.0545, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1777, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.5119, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0485, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0442, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.7519, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9362, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.4646, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.5737, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1818, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1815, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9427, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1956, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1653, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9459, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0424, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8547, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1547, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1713, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0388, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0356, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0394, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0424, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0371, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1647, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0872, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0561, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.6437, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1894, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1706, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0396, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.4603, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2174, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9293, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9369, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2087, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8741, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0315, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0609, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.4758, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0472, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.5375, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0365, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0419, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.5960, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.2750, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1884, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8455, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0546, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9425, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9230, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0461, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1647, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1621, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9285, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0453, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0405, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0568, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1736, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0720, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9672, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9390, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1840, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0527, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9630, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0381, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.4568, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.5642, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1849, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.7379, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.4558, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0316, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.1811, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0666, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.0357, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9345, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8628, device='cuda:0', grad_fn=<MaxBackward1>)

# %%
plt.figure(figsize=(200, 100))
plt.imshow(importance_map.T)
plt.xticks(np.arange(depth), ["t-{}".format(i) for i in range(depth,0,-1)], rotation=90)
plt.yticks(np.arange(6), ['X{}'.format(i) for i in range(6)])
# Out:
# ([<matplotlib.axis.YTick at 0x7f4da6d2e4e0>,
#   <matplotlib.axis.YTick at 0x7f4da6d2e630>,
#   <matplotlib.axis.YTick at 0x7f4da702e6d8>,
#   <matplotlib.axis.YTick at 0x7f4da7758048>,
#   <matplotlib.axis.YTick at 0x7f4da77585f8>,
#   <matplotlib.axis.YTick at 0x7f4da7758be0>],
#  [Text(0, 0, 'X0'),
#   Text(0, 1, 'X1'),
#   Text(0, 2, 'X2'),
#   Text(0, 3, 'X3'),
#   Text(0, 4, 'X4'),
#   Text(0, 5, 'X5')])

# %% [markdown]
# ### Signals with highest importance

# %%
#X3[t-80]

# %% [markdown]
# ### True dependencies

# %%
#X4[t] += X3[t-80]/(20 + X2[t-40])

# %%
TP = 1
FP = 0
FN = 1
precision3 = TP/(TP + FP + 1e-9)
recall3 = TP/(TP + FN + 1e-9)
precision3, recall3
# Out:
# (0.9999999989999999, 0.49999999975)

# %% [markdown]
# ### Predicting X5

# %%
y = pd.Series(X5).shift(-1).ffill().values
y = y[max_lag:]
y_train = y[:train_length]
y_test = y[train_length:]

y_train_min, y_train_max = y_train.min(axis=0), y_train.max(axis=0)

y_train = (y_train - y_train_min)/(y_train_max - y_train_min + 1e-9)
y_test = (y_test - y_train_min)/(y_train_max - y_train_min + 1e-9)

y_train_t = torch.Tensor(y_train)
y_test_t = torch.Tensor(y_test)

train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), shuffle=True, batch_size=256)
test_loader = DataLoader(TensorDataset(X_test_t, y_test_t), shuffle=False, batch_size=256)

# %%
#model = TCNModel(X_train_t.shape[2], num_channels=[32] * 9, kernel_size=3, dropout=0.0).cuda()
model = TCN(X_train_t.shape[2], 9).cuda()
opt = torch.optim.Adam(model.parameters(), lr=0.001)

loss = nn.MSELoss()

# %%
val_loss = 999
counter = 0

for e in range(epochs):
    train_loss = 0
    
    model.train()
    for batch_x, batch_y in tqdm_notebook(train_loader):
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()
        opt.zero_grad()
        output = model(batch_x)
        l = loss(output, batch_y)
        l.backward()
        opt.step()
        train_loss+=l.item()*batch_x.shape[0]
    true = []
    preds = []
    model.eval()
    with torch.no_grad():
        for batch_x, batch_y in test_loader:
            batch_
    for e in range(importance_calculation_steps):
        opt.zero_grad()
        model.zero_grad()
        model.eval()
        y = y.detach()
        M = torch.sigmoid(mask)
        x_hat = bx*M
        y_hat = model(x_hat)
        l = mse_loss(y_hat, y)
        l += regularizer_coeff1*torch.sum(torch.abs(M))
        ones = torch.zeros_like(bx)
        ones[M>0.5] = 1
        l += 0.5*bce_loss(M, ones)
        l.backward()
        opt.step()
    M = torch.sigmoid(mask)
    #ms = ms.detach().cpu().numpy()
    print(M.max())
    thresholds = {}
    with torch.no_grad():
        for t in np.linspace(M.min().item(), M.max().item(), 100):
            M_clone = M.clone()
            M_clone[M_clone>t] = 1
            M_clone[M_clone<=t] = 0
            x_hat = bx*M_clone
            y_hat = model(x_hat)
            l = mse_loss(y_hat, y)
            l += regularizer_coeff2*torch.sum(torch.abs(M_clone))
            thresholds[l.item()] = t
    t = thresholds[min(thresholds.keys())]
    M = M.detach().cpu().numpy()
    M[M>t] = 1
    M[M<=t] = 0
    importance_map.append(np.abs(M))

importance_map = np.concatenate(importance_map)
importance_map = np.mean(importance_map, axis=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if __name__ == '__main__':
# HBox(children=(FloatProgress(value=0.0, max=77.0), HTML(value='')))
# tensor(0.8858, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8675, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9096, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9470, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8821, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8859, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8784, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9429, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9166, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8421, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9242, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9362, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.7958, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9082, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9340, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9440, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8863, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8241, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8622, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8647, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9290, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8950, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8500, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9159, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9156, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8948, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9103, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9148, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8565, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8818, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8867, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8709, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9174, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9246, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8948, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8369, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8870, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9039, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9193, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8960, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8953, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8759, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9023, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8375, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9337, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8252, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8405, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9052, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8926, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.7912, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9110, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8772, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8831, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8683, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9101, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8786, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8975, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9063, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9269, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8768, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9325, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8987, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9681, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9277, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8921, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9072, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8842, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8680, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8955, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8993, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8973, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9101, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9154, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8563, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8818, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.8667, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0.9154, device='cuda:0', grad_fn=<MaxBackward1>)

# %%
plt.figure(figsize=(200, 100))
plt.imshow(importance_map.T)
plt.xticks(np.arange(depth), ["t-{}".format(i) for i in range(depth,0,-1)], rotation=90)
plt.yticks(np.arange(6), ['X{}'.format(i) for i in range(6)])
# Out:
# ([<matplotlib.axis.YTick at 0x7f4da7139a58>,
#   <matplotlib.axis.YTick at 0x7f4da7139d68>,
#   <matplotlib.axis.YTick at 0x7f4da6e17da0>,
#   <matplotlib.axis.YTick at 0x7f4da6401a20>,
#   <matplotlib.axis.YTick at 0x7f4da6401eb8>,
#   <matplotlib.axis.YTick at 0x7f4da6401710>],
#  [Text(0, 0, 'X0'),
#   Text(0, 1, 'X1'),
#   Text(0, 2, 'X2'),
#   Text(0, 3, 'X3'),
#   Text(0, 4, 'X4'),
#   Text(0, 5, 'X5')])

# %% [markdown]
# ### Signals with highest importance

# %%
#X1[t-20], X0[t-10]

# %% [markdown]
# ### True dependencies

# %%
#X5[t] += X0[t-10]*X1[t-20]+X2[t-110]*X4[t-120]+X4[t-210]*X5[t-270]

# %%
TP = 2
FP = 0
FN = 4
precision4 = TP/(TP + FP + 1e-9)
recall4 = TP/(TP + FN + 1e-9)
precision4, recall4
# Out:
# (0.9999999995, 0.33333333327777775)
